# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesdail/D205-PA/blob/main/D205PA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import DataFrame
import missingno as msno
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline



medical_data = pd.read_csv("medical_raw_data.csv")
print(medical_data)
medical_data.duplicated()
medical_data.drop_duplicates()

medical_data.isnull().sum()
msno.matrix(medical_data, fontsize=12, labels=True)


medical_data['Z_Score_Population']=stats.zscore(medical_data['Population'])

medical_data['Z_Score_Age']=stats.zscore(medical_data['Age'])

medical_data['Z_Score_Children']=stats.zscore(medical_data['Children'])

medical_data['Z_Score_Income']= stats.zscore(medical_data['Income'])

medical_data['Z_Score_VitD_levels']=stats.zscore(medical_data['VitD_levels'])

medical_data['Z_Score_Doc_visits']=stats.zscore(medical_data['Doc_visits'])

medical_data['Z_Score_Full_meals_eaten']=stats.zscore(medical_data['Full_meals_eaten'])

medical_data['Z_Score_VitD_supp']=stats.zscore(medical_data['VitD_supp'])

medical_data['Z_Score_Initial_days']=stats.zscore(medical_data['Initial_days'])

medical_data['Z_Score_TotalCharge']=stats.zscore(medical_data['TotalCharge'])

medical_data['Z_Score_Additional_charges']=stats.zscore(medical_data['Additional_charges'])

medical_data[['Population', 'Z_Score_Population', 'Age','Z_Score_Age', 'Children',
             'Z_Score_Children', 'Income', 'Z_Score_Income', 'VitD_levels',
            'Z_Score_VitD_levels', 'Doc_visits', 'Z_Score_Doc_visits', 'Full_meals_eaten',
           'Z_Score_Full_meals_eaten', 'VitD_supp', 'Z_Score_VitD_supp', 'Initial_days',
          'Z_Score_Initial_days', 'TotalCharge', 'Z_Score_TotalCharge',
         'Additional_charges', 'Z_Score_Additional_charges']].head

medical_data['Anxiety_Text'] = medical_data['Anxiety']
medical_data['Overweight_Text'] = medical_data['Overweight']

dict_anxiety = {"Anxiety_Text": {0: "No", 1:"Yes"}}
dict_overweight = {"Overweight_Text": {0: "No", 1:"Yes"}}

medical_data.replace(dict_anxiety, inplace=True)
medical_data.replace(dict_overweight, inplace=True)
# Out:
#       Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 0              1          1     C412403  8cd49b13-f45a-4b47-a2bd-173ffa932c2f
# 1              2          2     Z919181  d2450b70-0337-4406-bdbb-bc1037f1734c
# 2              3          3     F995323  a2057123-abf5-4a2c-abad-8ffe33512562
# 3              4          4     A879973  1dec528d-eb34-4079-adce-0d7a40e82205
# 4              5          5     C544523  5885f56b-d6da-43a3-8760-83583af94266
# ...          ...        ...         ...                                   ...
# 9995        9996       9996     B863060  a25b594d-0328-486f-a9b9-0567eb0f9723
# 9996        9997       9997     P712040  70711574-f7b1-4a17-b15f-48c54564b70f
# 9997        9998       9998     R778890  1d79569d-8e0f-4180-a207-d67ee4527d26
# 9998        9999       9999     E344109  f5a68e69-2a60-409b-a92f-ac0847b27db0
# 9999       10000      10000     I569847  bc482c02-f8c9-4423-99de-3db5e62a18d5
#
# ...
